# %%
from google.colab import drive
('/content/drive/MyDrive/data set /GOOG.csv')
# Out:
# '/content/drive/MyDrive/data set /GOOG.csv'

# %%
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('/content/drive/MyDrive/data set /GOOG.csv')
df.head(10)
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %%
# imported Sequential from keras.models
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 7s 92ms/step - loss: 0.0091 - mean_absolute_error: 0.0670 - val_loss: 0.0166 - val_mean_absolute_error: 0.1073
# Epoch 2/100
# 28/28 [==============================] - 2s 86ms/step - loss: 7.7070e-04 - mean_absolute_error: 0.0221 - val_loss: 0.0027 - val_mean_absolute_error: 0.0401
# Epoch 3/100
# 28/28 [==============================] - 3s 96ms/step - loss: 4.6624e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0015 - val_mean_absolute_error: 0.0308
# Epoch 4/100
# 28/28 [==============================] - 3s 101ms/step - loss: 4.1076e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0031 - val_mean_absolute_error: 0.0435
# Epoch 5/100
# 28/28 [==============================] - 3s 110ms/step - loss: 3.8788e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0019 - val_mean_absolute_error: 0.0330
# Epoch 6/100
# 28/28 [==============================] - 3s 112ms/step - loss: 4.1457e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0048 - val_mean_absolute_error: 0.0560
# Epoch 7/100
# 28/28 [==============================] - 3s 125ms/step - loss: 3.8142e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0026 - val_mean_absolute_error: 0.0383
# Epoch 8/100
# 28/28 [==============================] - 4s 145ms/step - loss: 3.4920e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0025 - val_mean_absolute_error: 0.0379
# Epoch 9/100
# 28/28 [==============================] - 3s 99ms/step - loss: 3.8661e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0023 - val_mean_absolute_error: 0.0358
# Epoch 10/100
# 28/28 [==============================] - 3s 110ms/step - loss: 3.4620e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0036 - val_mean_absolute_error: 0.0474
# Epoch 11/100
# 28/28 [==============================] - 4s 130ms/step - loss: 3.5356e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0034 - val_mean_absolute_error: 0.0452
# Epoch 12/100
# 28/28 [==============================] - 5s 169ms/step - loss: 3.2411e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0040 - val_mean_absolute_error: 0.0488
# Epoch 13/100
# 28/28 [==============================] - 3s 106ms/step - loss: 3.3783e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0034 - val_mean_absolute_error: 0.0436
# Epoch 14/100
# 28/28 [==============================] - 1s 51ms/step - loss: 3.2853e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0037 - val_mean_absolute_error: 0.0471
# Epoch 15/100
# 28/28 [==============================] - 1s 51ms/step - loss: 3.1363e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0048 - val_mean_absolute_error: 0.0552
# Epoch 16/100
# 28/28 [==============================] - 1s 52ms/step - loss: 3.1389e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0037 - val_mean_absolute_error: 0.0461
# Epoch 17/100
# 28/28 [==============================] - 1s 51ms/step - loss: 3.0274e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0038 - val_mean_absolute_error: 0.0465
# Epoch 18/100
# 28/28 [==============================] - 2s 69ms/step - loss: 2.9145e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0054 - val_mean_absolute_error: 0.0576
# Epoch 19/100
# 28/28 [==============================] - 3s 95ms/step - loss: 2.9581e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0066 - val_mean_absolute_error: 0.0662
# Epoch 20/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.8669e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0035 - val_mean_absolute_error: 0.0455
# Epoch 21/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.8920e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0043 - val_mean_absolute_error: 0.0510
# Epoch 22/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.8163e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0028 - val_mean_absolute_error: 0.0388
# Epoch 23/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.8346e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0027 - val_mean_absolute_error: 0.0383
# Epoch 24/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.6040e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0045 - val_mean_absolute_error: 0.0537
# Epoch 25/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.4919e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0038 - val_mean_absolute_error: 0.0482
# Epoch 26/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.5286e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0041 - val_mean_absolute_error: 0.0499
# Epoch 27/100
# 28/28 [==============================] - 2s 90ms/step - loss: 2.5213e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0041 - val_mean_absolute_error: 0.0503
# Epoch 28/100
# 28/28 [==============================] - 2s 86ms/step - loss: 2.3493e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0036 - val_mean_absolute_error: 0.0466
# Epoch 29/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.2201e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0029 - val_mean_absolute_error: 0.0406
# Epoch 30/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.3594e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0040 - val_mean_absolute_error: 0.0501
# Epoch 31/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.3633e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0026 - val_mean_absolute_error: 0.0381
# Epoch 32/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.4511e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0029 - val_mean_absolute_error: 0.0408
# Epoch 33/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.2108e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0032 - val_mean_absolute_error: 0.0443
# Epoch 34/100
# 28/28 [==============================] - 1s 51ms/step - loss: 2.2406e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0022 - val_mean_absolute_error: 0.0354
# Epoch 35/100
# 28/28 [==============================] - 2s 68ms/step - loss: 2.2324e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0017 - val_mean_absolute_error: 0.0302
# Epoch 36/100
# 28/28 [==============================] - 3s 95ms/step - loss: 2.0710e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0030 - val_mean_absolute_error: 0.0431
# Epoch 37/100
# 28/28 [==============================] - 2s 67ms/step - loss: 2.0283e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0040 - val_mean_absolute_error: 0.0510
# Epoch 38/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.1828e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0032 - val_mean_absolute_error: 0.0437
# Epoch 39/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.9333e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0014 - val_mean_absolute_error: 0.0273
# Epoch 40/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.9241e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0020 - val_mean_absolute_error: 0.0337
# Epoch 41/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.8678e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0027 - val_mean_absolute_error: 0.0399
# Epoch 42/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.7559e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0016 - val_mean_absolute_error: 0.0289
# Epoch 43/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.8201e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0025 - val_mean_absolute_error: 0.0390
# Epoch 44/100
# 28/28 [==============================] - 2s 88ms/step - loss: 1.7724e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0018 - val_mean_absolute_error: 0.0328
# Epoch 45/100
# 28/28 [==============================] - 2s 88ms/step - loss: 1.7846e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0015 - val_mean_absolute_error: 0.0291
# Epoch 46/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.7634e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0014 - val_mean_absolute_error: 0.0281
# Epoch 47/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.7200e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0027 - val_mean_absolute_error: 0.0416
# Epoch 48/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.7607e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0024 - val_mean_absolute_error: 0.0384
# Epoch 49/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.8445e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0013 - val_mean_absolute_error: 0.0267
# Epoch 50/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.7738e-04 - mean_absolute_error: 0.0095 - val_loss: 6.9026e-04 - val_mean_absolute_error: 0.0194
# Epoch 51/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.8958e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0010 - val_mean_absolute_error: 0.0233
# Epoch 52/100
# 28/28 [==============================] - 2s 66ms/step - loss: 1.7144e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0029 - val_mean_absolute_error: 0.0435
# Epoch 53/100
# 28/28 [==============================] - 2s 87ms/step - loss: 1.7146e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0014 - val_mean_absolute_error: 0.0270
# Epoch 54/100
# 28/28 [==============================] - 2s 74ms/step - loss: 1.7850e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0028 - val_mean_absolute_error: 0.0419
# Epoch 55/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.6069e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0018 - val_mean_absolute_error: 0.0323
# Epoch 56/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.4925e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0018 - val_mean_absolute_error: 0.0326
# Epoch 57/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.6302e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0025 - val_mean_absolute_error: 0.0397
# Epoch 58/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.4997e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0017 - val_mean_absolute_error: 0.0320
# Epoch 59/100
# 28/28 [==============================] - 1s 51ms/step - loss: 1.5333e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0022 - val_mean_absolute_error: 0.0369
# Epoch 60/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.4427e-04 - mean_absolute_error: 0.0086 - val_loss: 7.0894e-04 - val_mean_absolute_error: 0.0194
# Epoch 61/100
# 28/28 [==============================] - 2s 80ms/step - loss: 1.4197e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0016 - val_mean_absolute_error: 0.0313
# Epoch 62/100
# 28/28 [==============================] - 3s 95ms/step - loss: 1.4729e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0012 - val_mean_absolute_error: 0.0259
# Epoch 63/100
# 28/28 [==============================] - 2s 65ms/step - loss: 1.5358e-04 - mean_absolute_error: 0.0091 - val_loss: 7.3393e-04 - val_mean_absolute_error: 0.0198
# Epoch 64/100
# 28/28 [==============================] - 3s 97ms/step - loss: 1.4967e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0015 - val_mean_absolute_error: 0.0294
# Epoch 65/100
# 28/28 [==============================] - 2s 72ms/step - loss: 1.3879e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0023 - val_mean_absolute_error: 0.0395
# Epoch 66/100
# 28/28 [==============================] - 1s 51ms/step - loss: 1.5868e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0018 - val_mean_absolute_error: 0.0344
# Epoch 67/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.3648e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0019 - val_mean_absolute_error: 0.0356
# Epoch 68/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.3929e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0030 - val_mean_absolute_error: 0.0462
# Epoch 69/100
# 28/28 [==============================] - 3s 124ms/step - loss: 1.6266e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0015 - val_mean_absolute_error: 0.0314
# Epoch 70/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.3459e-04 - mean_absolute_error: 0.0083 - val_loss: 7.4455e-04 - val_mean_absolute_error: 0.0202
# Epoch 71/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.3598e-04 - mean_absolute_error: 0.0085 - val_loss: 8.9980e-04 - val_mean_absolute_error: 0.0224
# Epoch 72/100
# 28/28 [==============================] - 1s 54ms/step - loss: 1.2967e-04 - mean_absolute_error: 0.0082 - val_loss: 9.0642e-04 - val_mean_absolute_error: 0.0220
# Epoch 73/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.2817e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0010 - val_mean_absolute_error: 0.0242
# Epoch 74/100
# 28/28 [==============================] - 1s 51ms/step - loss: 1.1865e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0012 - val_mean_absolute_error: 0.0257
# Epoch 75/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.3482e-04 - mean_absolute_error: 0.0082 - val_loss: 5.3871e-04 - val_mean_absolute_error: 0.0169
# Epoch 76/100
# 28/28 [==============================] - 2s 79ms/step - loss: 1.2427e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0022 - val_mean_absolute_error: 0.0381
# Epoch 77/100
# 28/28 [==============================] - 3s 94ms/step - loss: 1.2132e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0013 - val_mean_absolute_error: 0.0278
# Epoch 78/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.3193e-04 - mean_absolute_error: 0.0082 - val_loss: 7.3209e-04 - val_mean_absolute_error: 0.0195
# Epoch 79/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.2952e-04 - mean_absolute_error: 0.0081 - val_loss: 7.5979e-04 - val_mean_absolute_error: 0.0209
# Epoch 80/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.1785e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0013 - val_mean_absolute_error: 0.0278
# Epoch 81/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.2271e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0014 - val_mean_absolute_error: 0.0291
# Epoch 82/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.1725e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0015 - val_mean_absolute_error: 0.0305
# Epoch 83/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.1051e-04 - mean_absolute_error: 0.0075 - val_loss: 8.3561e-04 - val_mean_absolute_error: 0.0214
# Epoch 84/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.2262e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0016 - val_mean_absolute_error: 0.0324
# Epoch 85/100
# 28/28 [==============================] - 2s 88ms/step - loss: 1.1174e-04 - mean_absolute_error: 0.0076 - val_loss: 3.8628e-04 - val_mean_absolute_error: 0.0143
# Epoch 86/100
# 28/28 [==============================] - 2s 78ms/step - loss: 1.1160e-04 - mean_absolute_error: 0.0076 - val_loss: 9.2115e-04 - val_mean_absolute_error: 0.0232
# Epoch 87/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.1208e-04 - mean_absolute_error: 0.0076 - val_loss: 8.3641e-04 - val_mean_absolute_error: 0.0216
# Epoch 88/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.3165e-04 - mean_absolute_error: 0.0083 - val_loss: 9.1860e-04 - val_mean_absolute_error: 0.0227
# Epoch 89/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.0852e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0014 - val_mean_absolute_error: 0.0282
# Epoch 90/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.0548e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0013 - val_mean_absolute_error: 0.0272
# Epoch 91/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.1108e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0010 - val_mean_absolute_error: 0.0243
# Epoch 92/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.0139e-04 - mean_absolute_error: 0.0071 - val_loss: 0.0020 - val_mean_absolute_error: 0.0354
# Epoch 93/100
# 28/28 [==============================] - 2s 71ms/step - loss: 1.0892e-04 - mean_absolute_error: 0.0074 - val_loss: 7.6451e-04 - val_mean_absolute_error: 0.0205
# Epoch 94/100
# 28/28 [==============================] - 2s 87ms/step - loss: 1.2292e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
# Epoch 95/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.1099e-04 - mean_absolute_error: 0.0074 - val_loss: 9.2056e-04 - val_mean_absolute_error: 0.0232
# Epoch 96/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.1092e-04 - mean_absolute_error: 0.0077 - val_loss: 4.0343e-04 - val_mean_absolute_error: 0.0146
# Epoch 97/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.1542e-04 - mean_absolute_error: 0.0076 - val_loss: 4.4297e-04 - val_mean_absolute_error: 0.0153
# Epoch 98/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.1825e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0013 - val_mean_absolute_error: 0.0293
# Epoch 99/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.0531e-04 - mean_absolute_error: 0.0072 - val_loss: 7.6612e-04 - val_mean_absolute_error: 0.0212
# Epoch 100/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.0809e-04 - mean_absolute_error: 0.0074 - val_loss: 7.3604e-04 - val_mean_absolute_error: 0.0207

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 14ms/step
# array([[0.40279987, 0.40041545],
#        [0.40197754, 0.3998337 ],
#        [0.39738914, 0.39557132],
#        [0.40228432, 0.40011555],
#        [0.40617272, 0.40382758]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1417.7587, 1410.366 ],
#        [1416.2343, 1409.2878],
#        [1407.7277, 1401.3882],
#        [1416.803 , 1409.8102],
#        [1424.0117, 1416.6898]], dtype=float32)

# %%
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1417.758667      1410.365967
# 2020-05-28  1396.86  1416.73     1416.234253      1409.287842
# 2020-05-29  1416.94  1428.92     1407.727661      1401.388184
# 2020-06-01  1418.39  1431.82     1416.802979      1409.810181
# 2020-06-02  1430.55  1439.22     1424.011719      1416.689819

# %%
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2421.569092      2402.319824
# 2021-06-10  2494.01  2521.60     2426.946533      2408.204590
# 2021-06-11  2524.92  2513.93     2443.500000      2423.953369
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
